# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Fri Apr  6 13:11:54 2018

@author: nick
"""

import datetime as dt
import pandas_datareader.data as web
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style

style.use('ggplot')
start=dt.datetime(2018,1,1)
end=dt.datetime(2018,4,1)
df=web.DataReader('TSLA', 'morningstar', start,end)
df.reset_index(inplace=True) #inplace sama kyk df=df.reset_index
df.set_index("Date", inplace=True)
df.to_csv('tsla.csv')
df=pd.read_csv('tsla.csv', parse_dates=True, index_col=0)
df['100ma']=df['Close'].rolling(window=100).mean()
print(df[['Open','High']].head())
print(df.tail())
df['Open'].plot()
plt.show()
# Out:
#               Open      High
# Date
# 2018-01-01  311.35  311.3500
# 2018-01-02  312.00  322.1099
# 2018-01-03  321.00  325.2500
# 2018-01-04  312.87  318.5500
# 2018-01-05  316.62  317.2400
#            Symbol   Close      High     Low    Open    Volume  100ma
# Date
# 2018-03-26   TSLA  304.18  307.5900  291.36  307.34   8375175    NaN
# 2018-03-27   TSLA  279.18  304.2700  277.18  304.00  13872029    NaN
# 2018-03-28   TSLA  257.78  268.6800  252.10  264.58  21001437    NaN
# 2018-03-29   TSLA  266.13  270.9599  248.21  256.49  15170749    NaN
# 2018-03-30   TSLA  266.13  266.1300  266.13  266.13         0    NaN
